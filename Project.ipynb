# %% [markdown]
# # PriceTrack: Unlocking Car Market Insights
#
# PriceTrack is a data science project designed to predict the valuation of second-hand cars based on key input parameters.
# Leveraging regression model, it provides data-driven insights to help buyers and sellers make informed decisions.

# %% [markdown]
# We will be using some common Python libraries, such as pandas, numpy, seaborn, and matplotlib.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# ## Importing Dataset
#
# We used the Quikr Car data set that comes from the (https://quikr.com) to carry out Exploratory Data Analysis.
#
# The dataset includes 892 cars (rows) and 6 features (columns).

# %%
df=pd.read_csv("quikr_car.csv")
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %% [markdown]
# ### Understanding the type of data we're dealing with

# %% [markdown]
# Starting with datatypes

# %%
df.info()
# categorize into types of variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# ## Data Preprocessing
# #### Converting columns to respective datatypes

# %% [markdown]
# #### a) Year Column
#
# Finding unique year values

# %%
print("Unique years: ", df["year"].unique())
# Out:
# Unique years:  ['2007' '2006' '2018' '2014' '2015' '2012' '2013' '2016' '2010' '2017'
#  '2008' '2011' '2019' '2009' '2005' '2000' '...' '150k' 'TOUR' '2003'
#  'r 15' '2004' 'Zest' '/-Rs' 'sale' '1995' 'ara)' '2002' 'SELL' '2001'
#  'tion' 'odel' '2 bs' 'arry' 'Eon' 'o...' 'ture' 'emi' 'car' 'able' 'no.'
#  'd...' 'SALE' 'digo' 'sell' 'd Ex' 'n...' 'e...' 'D...' ', Ac' 'go .'
#  'k...' 'o c4' 'zire' 'cent' 'Sumo' 'cab' 't xe' 'EV2' 'r...' 'zest']

# %% [markdown]
# Converting non-numeric values to numeric or NaN using ```errors="coerce"```, this step ensures there are no invalid values or errors before converting to integers

# %%
# Year can be estimated based on kilometers driven
df["year"] = pd.to_numeric(df["year"], errors='coerce').astype("Int64")
unique_years = df["year"].sort_values().unique()
print("Unique years: ", unique_years)
df.head()
# Out:
# Unique years:  <IntegerArray>
# [1995, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#  2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, <NA>]
# Length: 22, dtype: Int64
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %% [markdown]
# #### b) Km Driven Column
#
# Converting Kilometers to Integer, also making sure its value is more than 100

# %%
price_series = pd.to_numeric(df["kms_driven"].str.replace(r"\D", "", regex=True), errors="coerce").astype("Float64")

# Convert all entries to 0 where km is less than 100
price_series[price_series < 100] = pd.NA

df["kms_driven"] = price_series
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0     45000.0    Petrol
# 1        <NA>    Diesel
# 2     22000.0    Petrol
# 3     28000.0    Petrol
# 4     36000.0    Diesel

# %% [markdown]
# #### c) Price Column
#
# Converting Price to Integer

# %%
price_series = pd.to_numeric(df["Price"].str.replace(r"\D", "", regex=True), errors="coerce").astype("Int64")

df["Price"] = price_series
df.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        <NA>
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018    <NA>     22000.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %% [markdown]
# #### d) Fuel Type Column
#
# Converting Fuel Type to category

# %%
df["fuel_type"] = df["fuel_type"].astype("category")
df.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000     45000.0
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000        <NA>
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018    <NA>     22000.0
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000     28000.0
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000     36000.0
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        842 non-null    Int64
#  3   Price       857 non-null    Int64
#  4   kms_driven  823 non-null    Float64
#  5   fuel_type   837 non-null    category
# dtypes: Float64(1), Int64(2), category(1), object(2)
# memory usage: 38.6+ KB

# %%
df.describe()
# Out:
#               year          Price    kms_driven
# count        842.0          857.0         823.0
# mean   2012.523753  404688.534422   46848.72175
# std       4.024601  465536.544629  34213.169031
# min         1995.0        30000.0         100.0
# 25%         2010.0       175000.0       27000.0
# 50%         2013.0       299999.0       41000.0
# 75%         2015.0       485000.0       57461.5
# max         2019.0      8500003.0      400000.0

# %% [markdown]
# ## Data Cleaning
#
# #### Handling Missing values

# %%
df.isna().sum()
# Out:
# name           0
# company        0
# year          50
# Price         35
# kms_driven    69
# fuel_type     55
# dtype: int64

# %%
nokms_mask = df["kms_driven"].isna()
noyear_mask = df["year"].isna()
noprice_mask = df["Price"].isna()
nofuel_mask = df["fuel_type"].isna()

tempdf = df[((nokms_mask) & (noyear_mask) & (noprice_mask) & (nofuel_mask))]
print(f"{tempdf.shape[0]} rows are deleted because they don't have any of kms_driven, year, price or fuel_type")
df.drop(axis="index", inplace=True, index=tempdf.index)
print("Remaining dataset:")
df
# Out:
# 12 rows are deleted because they don't have any of kms_driven, year, price or fuel_type
# Remaining dataset:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018    <NA>
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# ..                                      ...        ...   ...     ...
# 887                                      Ta       Tara  <NA>  310000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#      kms_driven fuel_type
# 0       45000.0    Petrol
# 1          <NA>    Diesel
# 2       22000.0    Petrol
# 3       28000.0    Petrol
# 4       36000.0    Diesel
# ..          ...       ...
# 887        <NA>       NaN
# 888     27000.0    Diesel
# 889     40000.0    Diesel
# 890        <NA>       NaN
# 891        <NA>       NaN
#
# [880 rows x 6 columns]

# %% [markdown]
# Removing Rows with Invalid names

# %%
invalid_name_mask = df["name"].str.len()<5
print("Removed", df[invalid_name_mask].shape[0], "rows with invalid name")

df.drop(axis="index", index=df[invalid_name_mask].index, inplace=True)

df
# Out:
# Removed 3 rows with invalid name
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018    <NA>
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#      kms_driven fuel_type
# 0       45000.0    Petrol
# 1          <NA>    Diesel
# 2       22000.0    Petrol
# 3       28000.0    Petrol
# 4       36000.0    Diesel
# ..          ...       ...
# 886    132000.0    Petrol
# 888     27000.0    Diesel
# 889     40000.0    Diesel
# 890        <NA>       NaN
# 891        <NA>       NaN
#
# [877 rows x 6 columns]

# %% [markdown]
# Removing LPG and \<NA\> fuel type records

# %%
print("Before:")
print(df["fuel_type"].value_counts())
print("Empty records:",df["fuel_type"].isna().sum())

# Drop LPG records
df = df[(df["fuel_type"] != "LPG") & (~df["fuel_type"].isna())].reset_index(drop=True)
df["fuel_type"] = df["fuel_type"].cat.remove_unused_categories()

print("\nAfter:")
print(df["fuel_type"].value_counts())
print("Empty records:",df["fuel_type"].isna().sum())
# Out:
# Before:
# Petrol    440
# Diesel    395
# LPG         2
# Name: fuel_type, dtype: int64
# Empty records: 40
#
# After:
# Petrol    440
# Diesel    395
# Name: fuel_type, dtype: int64
# Empty records: 0

# %% [markdown]
# Finding the average kilometers driven

# %%
mean_km = int(df.loc[~nokms_mask, "kms_driven"].mean())
mean_km
# Out:
# 46822

# %% [markdown]
# Replacing NaN with Mean Kms where **Year** & **Kms_driven** both are missing

# %%
df.loc[(noyear_mask) & (nokms_mask), "kms_driven"] = mean_km
df.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price         21
# kms_driven    14
# fuel_type      0
# dtype: int64

# %%
base_year = unique_years.max()
df["Age"] = base_year - df["year"] + 1
useful_df = df.loc[(~nokms_mask) & (~noyear_mask)]

df["Annual_Km_Driven"] = useful_df.loc[:,"kms_driven"] / useful_df.loc[:,"Age"]
mean_table = df[~df["Annual_Km_Driven"].isna()].groupby("fuel_type")["Annual_Km_Driven"].mean()
print(mean_table)
mean_table = mean_table.to_dict()
# Out:
# fuel_type
# Diesel    9833.688496
# Petrol    5134.568259
# Name: Annual_Km_Driven, dtype: Float64

# %% [markdown]
# Filling the empty Annual_Km_Driven records with mean values based on their fuel type

# %%
df['Annual_Km_Driven'].fillna(df['fuel_type'].map(mean_table), inplace=True)
df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018    <NA>
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# ..                                      ...       ...   ...     ...
# 830              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 831               Tata Indica V2 DLE BS III      Tata  2009  110000
# 832                    Toyota Corolla Altis    Toyota  2009  300000
# 833                     Tata Zest XM Diesel      Tata  2018  260000
# 834                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type  Age  Annual_Km_Driven
# 0       45000.0    Petrol   13       3461.538462
# 1          <NA>    Diesel   14       9833.688496
# 2       22000.0    Petrol    2           11000.0
# 3       28000.0    Petrol    6       4666.666667
# 4       36000.0    Diesel    6            6000.0
# ..          ...       ...  ...               ...
# 830     50000.0    Petrol    9       5555.555556
# 831     30000.0    Diesel   11       2727.272727
# 832    132000.0    Petrol   11           12000.0
# 833     27000.0    Diesel    2           13500.0
# 834     40000.0    Diesel    7       5714.285714
#
# [835 rows x 8 columns]

# %%
df["kms_driven"].fillna(df["Annual_Km_Driven"] * df["Age"], inplace=True)
df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018    <NA>
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# ..                                      ...       ...   ...     ...
# 830              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 831               Tata Indica V2 DLE BS III      Tata  2009  110000
# 832                    Toyota Corolla Altis    Toyota  2009  300000
# 833                     Tata Zest XM Diesel      Tata  2018  260000
# 834                      Mahindra Quanto C8  Mahindra  2013  390000
#
#         kms_driven fuel_type  Age  Annual_Km_Driven
# 0          45000.0    Petrol   13       3461.538462
# 1    137671.638942    Diesel   14       9833.688496
# 2          22000.0    Petrol    2           11000.0
# 3          28000.0    Petrol    6       4666.666667
# 4          36000.0    Diesel    6            6000.0
# ..             ...       ...  ...               ...
# 830        50000.0    Petrol    9       5555.555556
# 831        30000.0    Diesel   11       2727.272727
# 832       132000.0    Petrol   11           12000.0
# 833        27000.0    Diesel    2           13500.0
# 834        40000.0    Diesel    7       5714.285714
#
# [835 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# name                 0
# company              0
# year                 0
# Price               21
# kms_driven           0
# fuel_type            0
# Age                  0
# Annual_Km_Driven     0
# dtype: int64

# %% [markdown]
# - Price Column

# %%
invalid_row_count = df["Price"].str.contains(r'[a-zA-Z]').sum()
print("Number of Invalid Price Rows:", invalid_row_count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[344], line 1
# ----> 1 invalid_row_count = df["Price"].str.contains(r'[a-zA-Z]').sum()
#       2 print("Number of Invalid Price Rows:", invalid_row_count)
#
# File c:\Users\jayso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File c:\Users\jayso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\jayso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\jayso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# Converting **Price** to numeric datatype (cleaning non-numeric characters)
# <br />
# If Invalid value is found, we will fill it with 0 for now

# %%
df["Price"] = pd.to_numeric(df["Price"].str.replace(r'\D', '', regex=True), errors='coerce').fillna(0).astype(int)
df["Price"].head()
# Out:
# 0     80000
# 1    425000
# 2         0
# 3    325000
# 4    575000
# Name: Price, dtype: int64

# %% [markdown]
# Here we can see that only **kms_driven** and **fuel_type** columns have null values

# %%
df["year"].unique()
# Out:
# array([2007, 2006, 2018, 2014, 2015, 2012, 2013, 2016, 2010, 2017, 2008,
#        2011, 2019, 2009, 2005, 2000,    0, 2003, 2004, 1995, 2002, 2001])

# %%
# Convert 'name', 'company', 'fuel_type' to string (if not already)
ds1["name"] = ds1["name"].astype(str)
ds1["company"] = ds1["company"].astype(str)
ds1["fuel_type"] = ds1["fuel_type"].astype(str)

# Convert 'Price' and 'kms_driven' to numeric (cleaning non-numeric characters)
ds1["Price"] = pd.to_numeric(ds1["Price"].str.replace(r'\D', '', regex=True), errors='coerce').fillna(0).astype(int)
ds1["kms_driven"] = pd.to_numeric(ds1["kms_driven"].str.replace(r'\D', '', regex=True), errors='coerce').fillna(0).astype(int)

# Save the cleaned dataset
ds1.to_csv("my_cleaned_file.csv", index=False)

print("Data types successfully converted and saved!")
# Out:
# Data types successfully converted and saved!
